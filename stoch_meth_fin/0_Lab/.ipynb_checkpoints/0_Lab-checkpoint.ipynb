# %% [markdown]
# # First Lab, Lab0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import yfinance as yf

# %%
ticker = 'NVDA'
start_date = '2020-01-01'
end_date = '2024-12-31'

# Re-download the stock data to update the empty DataFrame
stock_data = yf.download(ticker, start=start_date, end=end_date)
print(stock_data)

# Plot the stock data
plt.figure(figsize=(10, 5))
plt.plot(stock_data['Close'], label='Close Price')
plt.title(f'{ticker} Stock Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NVDA']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# Empty DataFrame
# Columns: [(Adj Close, NVDA), (Close, NVDA), (High, NVDA), (Low, NVDA), (Open, NVDA), (Volume, NVDA)]
# Index: []

# %% [markdown]
# Unicorn: great market company with capitaization >1 billion
#
# Notes:
# Increasing factor
# $u=exp(3/12 *\sigma_Yearly)$
#
# (three months, annual volatility)
#
# Decreasing factor has a minus
#
# Std is the daily volatility, not the annual, so I need to compute the daily into the annual.
# Importan rule of thumb: In order to shift from sigma with different frequency, it is optimal to work with the vairance because it aggregates for difference frequencies. Variance of two days = 2* variance of one day.
#
# $Annual volatility=daily volatility * \sqrt(time diff)$
#
# The only missing factor is the risk.
# $\frac(\exp(RT)-\exp(t))(su - sd)$
